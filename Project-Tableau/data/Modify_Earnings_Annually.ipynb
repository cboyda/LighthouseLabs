# %% [markdown]
# <a href="https://colab.research.google.com/github/cboyda/LighthouseLabs/blob/main/Modify_Earnings_Annually.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# how to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets/weekly_earnings.csv')

# %%
df.head(5)
# Out:
#     sid                                    id  position  created_at  \
# 0  5554  8D0D0120-53D5-4A3D-B68F-D5BAFA1B9F24      5554  1435599444
# 1  5555  B8156EED-2420-4B71-A56C-57DED1FA7CEC      5555  1435599444
# 2  5556  A8D7795E-40FA-4923-AB52-CA8536DAAD7A      5556  1435599444
# 3  5557  8373DAD3-2886-4DAD-AFE8-84DB8C0F414E      5557  1435599444
# 4  5558  05DB3E97-35EC-4F75-891B-3F6C696CDEE0      5558  1435599444
#
#    created_meta  updated_at  updated_meta  meta                 When  \
# 0        710753  1435599444        710753   NaN  2001-01-01T00:00:00
# 1        710753  1435599444        710753   NaN  2001-02-01T00:00:00
# 2        710753  1435599444        710753   NaN  2001-03-01T00:00:00
# 3        710753  1435599444        710753   NaN  2001-04-01T00:00:00
# 4        710753  1435599444        710753   NaN  2001-05-01T00:00:00
#
#                                                NAICS  ...  BritishColumbia  \
# 0  Industrial aggregate excluding unclassified bu...  ...           660.48
# 1  Industrial aggregate excluding unclassified bu...  ...           659.33
# 2  Industrial aggregate excluding unclassified bu...  ...           654.07
# 3  Industrial aggregate excluding unclassified bu...  ...           657.15
# 4  Industrial aggregate excluding unclassified bu...  ...           653.23
#
#    Canada  Manitoba  NewBrunswick  NewfoundlandAndLabrador  NovaScotia  \
# 0  658.02    578.95        584.75                   594.00      571.28
# 1  655.79    580.63        585.11                   591.92      570.06
# 2  655.88    578.67        584.13                   593.47      570.70
# 3  654.09    576.36        580.92                   591.96      568.70
# 4  650.02    571.84        578.44                   588.19      567.96
#
#    Ontario  PrinceEdwardIsland  Quebec  Saskatchewan
# 0   698.57              535.65  624.81        596.53
# 1   693.69              532.02  623.93        595.09
# 2   697.08              534.71  622.94        589.09
# 3   693.73              522.50  619.12        589.37
# 4   688.27              522.31  618.90        587.41
#
# [5 rows x 21 columns]

# %%
# drop usesless columns
df.drop(['sid', 'id','position','created_at','created_meta','updated_at','updated_meta','meta','NAICS',], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#                   When  Alberta  BritishColumbia  Canada  Manitoba  \
# 0  2001-01-01T00:00:00   670.54           660.48  658.02    578.95
# 1  2001-02-01T00:00:00   670.52           659.33  655.79    580.63
# 2  2001-03-01T00:00:00   668.49           654.07  655.88    578.67
# 3  2001-04-01T00:00:00   671.71           657.15  654.09    576.36
# 4  2001-05-01T00:00:00   664.45           653.23  650.02    571.84
#
#    NewBrunswick  NewfoundlandAndLabrador  NovaScotia  Ontario  \
# 0        584.75                   594.00      571.28   698.57
# 1        585.11                   591.92      570.06   693.69
# 2        584.13                   593.47      570.70   697.08
# 3        580.92                   591.96      568.70   693.73
# 4        578.44                   588.19      567.96   688.27
#
#    PrinceEdwardIsland  Quebec  Saskatchewan
# 0              535.65  624.81        596.53
# 1              532.02  623.93        595.09
# 2              534.71  622.94        589.09
# 3              522.50  619.12        589.37
# 4              522.31  618.90        587.41

# %%
df_clean = pd.DataFrame()

# %%
# rename bad province headings
# Define the new column names
new_columns = ['Date', 'Alberta', 'British Columbia', 'Canada', 'Manitoba', 'New Brunswick',
               'Newfoundland and Labrador', 'Nova Scotia', 'Ontario', 'Prince Edward Island',
               'Quebec', 'Saskatchewan']

# Rename the columns in the DataFrame
df.columns = new_columns

# %%
# Create a list of Canadian provinces by excluding the first column ("When")
provinces = df.columns[1:].tolist()
provinces
# Out:
# ['Alberta',
#  'British Columbia',
#  'Canada',
#  'Manitoba',
#  'New Brunswick',
#  'Newfoundland and Labrador',
#  'Nova Scotia',
#  'Ontario',
#  'Prince Edward Island',
#  'Quebec',
#  'Saskatchewan']

# %%
# Extract year from the "When" column
df['Year'] = pd.to_datetime(df['Date']).dt.year

# %%
# Initialize an empty DataFrame to store the cleaned data
df_clean = pd.DataFrame(columns=['Date', 'Location', 'Earnings'])

# Iterate over each year and province
for year in df['Year'].unique():
    for province in provinces:
        # Filter the data for the current year and province
        year_province_data = df[(df['Year'] == year)][['Date', province]]
        
        # Calculate the sum of earnings for the current year and province
        earnings_sum = year_province_data[province].sum()
        
        # Create a temporary DataFrame with the current data
        temp_df = pd.DataFrame({'Date': str(year), 'Location': province, 'Earnings': earnings_sum}, index=[0])
        
        # Concatenate the temporary DataFrame with df_clean
        df_clean = pd.concat([df_clean, temp_df], ignore_index=True)

# %%
df_clean
# Out:
#      Date              Location  Earnings
# 0    2001               Alberta   8103.19
# 1    2001      British Columbia   7892.30
# 2    2001                Canada   7885.42
# 3    2001              Manitoba   7008.45
# 4    2001         New Brunswick   7070.19
# ..    ...                   ...       ...
# 160  2015           Nova Scotia   3317.93
# 161  2015               Ontario   3853.82
# 162  2015  Prince Edward Island   3196.67
# 163  2015                Quebec   3446.63
# 164  2015          Saskatchewan   3939.95
#
# [165 rows x 3 columns]

# %%
# write dataframe to csv file for Tableau
df_clean.to_csv('/content/drive/MyDrive/Colab Notebooks/datasets/annual_earnings.csv', index=False)
