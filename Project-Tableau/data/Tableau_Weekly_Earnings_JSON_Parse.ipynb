# %% [markdown]
# <a href="https://colab.research.google.com/github/cboyda/LighthouseLabs/blob/main/Tableau_Weekly_Earnings_JSON_Parse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# how to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import pprint

data = json.load(open('/content/drive/MyDrive/Colab Notebooks/datasets/weekly_earnings.json', 'rb'))
pprint.pprint(data, depth=1)
# Out:
# {'data': [...], 'meta': {...}}

# %%
# Extract the relevant information from the JSON data
columns = json_data['meta']['view']['columns']
data = json_data['data']

# Create a list of column names
column_names = [column['name'] for column in columns]

# Create a list of rows
rows = [row for row in data]

# Create the dataframe
df = pd.DataFrame(rows, columns=column_names)

# Print the dataframe
df
# Out:
#       sid                                    id  position  created_at  \
# 0    5554  8D0D0120-53D5-4A3D-B68F-D5BAFA1B9F24      5554  1435599444
# 1    5555  B8156EED-2420-4B71-A56C-57DED1FA7CEC      5555  1435599444
# 2    5556  A8D7795E-40FA-4923-AB52-CA8536DAAD7A      5556  1435599444
# 3    5557  8373DAD3-2886-4DAD-AFE8-84DB8C0F414E      5557  1435599444
# 4    5558  05DB3E97-35EC-4F75-891B-3F6C696CDEE0      5558  1435599444
# ..    ...                                   ...       ...         ...
# 167  5721  929B44CE-29DA-42D8-B7C3-C87C70D4C383      5721  1435599444
# 168  5722  F8CF4AB6-378A-4075-8BE7-6195EE417848      5722  1435599444
# 169  5723  F7A31164-A7FE-467F-A9F7-8A06954FB391      5723  1435599444
# 170  5724  58A68982-BF09-4DA2-9C86-094D9F52BB8F      5724  1435599444
# 171  5725  21789CE9-CD5C-4B1F-BAFF-B3D7C45E6F25      5725  1435599444
#
#     created_meta  updated_at updated_meta  meta                 When  \
# ...

# %%
# write dataframe to csv file for Tableau
df.to_csv('/content/drive/MyDrive/Colab Notebooks/datasets/weekly_earnings.csv', index=False)

# %% [markdown]
# ## Exploring Data

# %%
def print_json_structure(data, indent=0):
    if isinstance(data, dict):
        for key, value in data.items():
            print(f"{' ' * indent}{key}:")
            print_json_structure(value, indent + 2)
    elif isinstance(data, list):
        for item in data:
            print_json_structure(item, indent + 2)
    else:
        print(f"{' ' * indent}- {data}")

# Load the JSON file
with open('/content/drive/MyDrive/Colab Notebooks/datasets/weekly_earnings.json') as file:
    json_data = json.load(file)

# Print the structure
print_json_structure(json_data)
# Out:
# meta:
#   view:
#     id:
#       - gjxb-ck3u
#     name:
#       - Average Weekly Earnings
#     attribution:
#       - Statistics Canada
#     attributionLink:
#       - http://www5.statcan.gc.ca/cansim/a26?lang=eng&retrLang=eng&id=2810026&paSer=&pattern=&stByVal=1&p1=1&p2=-1&tabMode=dataTable&csid=
#     averageRating:
#       - 0
#     createdAt:
#       - 1391094794
#     description:
#       - Average weekly earnings are derived by dividing total weekly earnings (including overtime earnings) by the number of employees. This data is compiled from the Survey of Employment, Payrolls and Hours which is a business census of non-farm payroll employees.
#     displayType:
#       - table
#     downloadCount:
#       - 569
#     indexUpdatedAt:
#       - 1435600866
#     newBackend:
#       - False
#     numberOfComments:
#       - 0
#     oid:
#       - 7258663
#     publicationAppendEnabled:
#       - False
#     publicationDate:
#       - 1391795164
#     publicationGroup:
# ...

# %%
# this would have worked if the column names were part of the data

# Extracting the values from the JSON data
values = [value for value in json_data['data']]

# Creating a DataFrame from data: values
df_partial = pd.DataFrame(values).apply(pd.Series)

# Print the DataFrame
df_partial
# Out:
#        0                                     1     2           3       4   \
# 0    5554  8D0D0120-53D5-4A3D-B68F-D5BAFA1B9F24  5554  1435599444  710753
# 1    5555  B8156EED-2420-4B71-A56C-57DED1FA7CEC  5555  1435599444  710753
# 2    5556  A8D7795E-40FA-4923-AB52-CA8536DAAD7A  5556  1435599444  710753
# 3    5557  8373DAD3-2886-4DAD-AFE8-84DB8C0F414E  5557  1435599444  710753
# 4    5558  05DB3E97-35EC-4F75-891B-3F6C696CDEE0  5558  1435599444  710753
# ..    ...                                   ...   ...         ...     ...
# 167  5721  929B44CE-29DA-42D8-B7C3-C87C70D4C383  5721  1435599444  710753
# 168  5722  F8CF4AB6-378A-4075-8BE7-6195EE417848  5722  1435599444  710753
# 169  5723  F7A31164-A7FE-467F-A9F7-8A06954FB391  5723  1435599444  710753
# 170  5724  58A68982-BF09-4DA2-9C86-094D9F52BB8F  5724  1435599444  710753
# 171  5725  21789CE9-CD5C-4B1F-BAFF-B3D7C45E6F25  5725  1435599444  710753
#
#              5       6     7                    8   \
# ...

# %%
# Extracting the values from the JSON data
values = [item['name'] for item in json_data['meta']['view']['columns']]

# Creating a DataFrame from the values and parsing them into separate columns
df_columns = pd.DataFrame(values)
df_columns = df_columns.apply(lambda x: pd.Series(x))
df_columns
# Out:
#                           0
# 0                       sid
# 1                        id
# 2                  position
# 3                created_at
# 4              created_meta
# 5                updated_at
# 6              updated_meta
# 7                      meta
# 8                      When
# 9                     NAICS
# 10                  Alberta
# 11          BritishColumbia
# 12                   Canada
# 13                 Manitoba
# 14             NewBrunswick
# 15  NewfoundlandAndLabrador
# 16               NovaScotia
# 17                  Ontario
# 18       PrinceEdwardIsland
# 19                   Quebec
# 20             Saskatchewan
