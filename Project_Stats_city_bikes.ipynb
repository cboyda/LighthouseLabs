# %% [markdown]
# <a href="https://colab.research.google.com/github/cboyda/LighthouseLabs/blob/main/Project_Stats_city_bikes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice. Ideas gained from https://medium.com/@ajosegun_/real-time-dashboard-in-python-b8c9a9c4e050

# %%
import requests
import pandas as pd
import plotly.express as px
import datetime

# %% [markdown]
# ## Experimentation with JSON

# %%
# experiements: first grab main city_bikes JSON results.
city_bikes = requests.get("http://api.citybik.es/v2/networks").json()

# %%
# city_bikes # list all api returns
# {'networks': [{'company': ['ЗАО «СитиБайк»'],
#    'href': '/v2/networks/velobike-moscow',
#    'id': 'velobike-moscow',
#    'location': {'city': 'Moscow',
#     'country': 'RU',
#     'latitude': 55.75,
#     'longitude': 37.616667},
#    'name': 'Velobike'},
#   {'company': ['Urban Infrastructure Partner'],
#    'href': '/v2/networks/baerum-bysykkel',
#    'id': 'baerum-bysykkel',
#    'location': {'city': 'Bærum',
#     'country': 'NO',
#     'latitude': 59.89455,
#     'longitude': 10.546343},
#    'name': 'Bysykkel'},...

# %%
len(city_bikes['networks'])
# Out:
# 611

# %%
dfs = pd.DataFrame()
for network in city_bikes['networks']:
    #print(network['id'])
    dfs["id"]=(network['id'])
    dfs["city"]=(network['location']['city'])

# %%
import pandas as pd

dfs = pd.DataFrame()

for network in city_bikes['networks']:
    network_id = network['id']
    city = network['location']['city']
    latitude = network['location']['latitude']
    longitude = network['location']['longitude']
    row = pd.DataFrame({'id': [network_id], 'city': [city], 'latitude': [latitude], 'longitude': [longitude]})
    dfs = pd.concat([dfs, row], ignore_index=True)
print(dfs)
# Out:
#                             id      city   latitude  longitude
# 0              velobike-moscow    Moscow  55.750000  37.616667
# 1              baerum-bysykkel     Bærum  59.894550  10.546343
# 2             bicincitta-siena     Siena  43.318600  11.330600
# 3          cyclopolis-maroussi  Maroussi  38.056872  23.808330
# 4            cycle-hire-slough    Slough  51.511350  -0.591562
# ..                         ...       ...        ...        ...
# 606             publibike-bern      Bern  46.948410   7.437670
# 607   publibike-sottoceneri-ti    Lugano  46.004910   8.952440
# 608         publibike-fribourg  Fribourg  46.805708   7.160339
# 609  publibike-lausanne-morges  Lausanne  46.516649   6.629480
# 610             publibike-sion      Sion  46.228227   7.358901
#
# [611 rows x 4 columns]

# %%
dfs
# Out:
#                             id      city   latitude  longitude
# 0              velobike-moscow    Moscow  55.750000  37.616667
# 1              baerum-bysykkel     Bærum  59.894550  10.546343
# 2             bicincitta-siena     Siena  43.318600  11.330600
# 3          cyclopolis-maroussi  Maroussi  38.056872  23.808330
# 4            cycle-hire-slough    Slough  51.511350  -0.591562
# ..                         ...       ...        ...        ...
# 606             publibike-bern      Bern  46.948410   7.437670
# 607   publibike-sottoceneri-ti    Lugano  46.004910   8.952440
# 608         publibike-fribourg  Fribourg  46.805708   7.160339
# 609  publibike-lausanne-morges  Lausanne  46.516649   6.629480
# 610             publibike-sion      Sion  46.228227   7.358901
#
# [611 rows x 4 columns]

# %%
# Step 1: Function to grab main city_bikes JSON results.

def get_city_data(city):
  city_bikes = requests.get("http://api.citybik.es/v2/networks").json()

  list_of_dicts = []
  for city_bike_dict in city_bikes['networks']:
    new_city = city_bike_dict['location']['city']
    if new_city.lower() == city.lower():
      list_of_dicts.append(city_bike_dict)
  return list_of_dicts

# %%
get_city_data("Paris")
# SAMPLE RESULTS:
# [{'company': None,
#   'ebikes': True,
#   'gbfs_href': 'https://velib-metropole-opendata.smoove.pro/opendata/Velib_Metropole/gbfs.json',
#   'href': '/v2/networks/velib',
#   'id': 'velib',
#   'license': {'name': 'OPEN LICENCE 2.0',
#    'url': 'etalab.gouv.fr/wp-content/uploads/2018/11/open-licence.pdf'},
#   'location': {'city': 'Paris',
#    'country': 'FR',
#    'latitude': 48.856614,
#    'longitude': 2.3522219},
#   'name': "Vélib' Métropole"}]
# Out:
# [{'company': None,
#   'ebikes': True,
#   'gbfs_href': 'https://velib-metropole-opendata.smoove.pro/opendata/Velib_Metropole/gbfs.json',
#   'href': '/v2/networks/velib',
#   'id': 'velib',
#   'license': {'name': 'OPEN LICENCE 2.0',
#    'url': 'etalab.gouv.fr/wp-content/uploads/2018/11/open-licence.pdf'},
#   'location': {'city': 'Paris',
#    'country': 'FR',
#    'latitude': 48.856614,
#    'longitude': 2.3522219},
#   'name': "Vélib' Métropole"}]

# %%
# What city names exist to choose from?
sorted(dfs['city'].unique())
# Out:
# ['10vorWien',
#  'A Coruña',
#  'Aachen',
#  'Abu Dhabi',
#  'Acquarica del Capo',
#  'Acquaviva delle fonti',
#  'Agen',
#  'Aigialeia',
#  'Alba',
#  'Alghero',
#  'Almaty',
#  'Altea',
#  'Amiens',
#  'Andria',
#  'Anklam',
#  'Ann Arbor, MI',
#  'Antalya',
#  'Antwerpen',
#  'Aracajú',
#  'Arezzo',
#  'Ascoli Piceno',
#  'Aspen, CO',
#  'Assemini',
#  'Astana',
#  'Athens',
#  'Atlanta, GA',
#  'Auckland Waterfront',
#  'Augsburg',
#  'Austin, TX',
#  'Avignon',
#  'Bad Oeynhausen',
#  'Bangkok',
#  'Banja Luka',
#  'Barcellona Pozzo di Gotto',
#  'Barcelona',
#  'Batumi',
#  'Belfast',
#  'Belfort',
#  'Belo Horizonte',
#  'Belém',
#  'Benidorm',
#  'Bensheim',
#  'Bergamo',
#  'Bergen',
#  'Bergisches e-Bike',
#  'Berlin',
#  'Bern',
#  'Berounsko',
#  'Besançon',
#  'Bhopal',
#  'Bianzone',
#  'Białystok',
#  'Bielefeld',
#  'Biella',
#  'Bielsko-Biała',
#  'Bilbao',
#  'Bochum',
#  'Boise, ID',
#  'Bonn',
#  'Bordeaux',
#  'Borgarello',
#  'Boston, MA',
#  'Bottrop',
#  'Boulder, CO',
#  'Bourg-en-Bresse',
#  'Brancaleone',
#  'Brasília',
#  'Bratislava',
#  'Braunschweig',
#  'Bremen',
#  'Brescia',
#  'Brindisi',
#  'Brinje',
#  'Brno',
#  'Brunel University',
#  'Bruxelles',
#  'Budapest',
#  'Buenos Aires',
#  'Buffalo, NY',
#  'Busto Arsizio',
#  'Byblos',
#  'Bydgoszcz',
#  'Bærum',
#  'Bürstadt',
#  'Cagliari',
#  'Calais',
#  'Cancún',
#  'Carbonia',
#  'Cardiff',
#  'Carrara',
#  'Casaletto Spartano',
#  "Cassano d'Adda",
#  'Castel Guelfo di Bologna',
#  'Castellucchio',
#  'Cd de México',
#  'Celje',
#  'Cergy',
#  'Cernusco sul Naviglio - Pioltello - Carugate',
#  'Cesena',
#  'Charlotte, NC',
#  'Chattanooga, TN',
#  'Chełm',
#  'Chicago, IL',
#  'Chivasso',
#  'Christchurch',
#  'Ciechanów',
#  'Cincinnati, OH',
#  'Cisterna di Latina',
#  'Civitavecchia',
#  'Clermont-Ferrand',
#  'Cluj-Napoca',
#  'Columbus, OH',
#  "Communauté d'agglomération Seine-Eure",
#  'Como',
#  'Cork',
#  'Cremona',
#  'Créteil',
#  'Cuneo',
#  'Curtin University, Perth, WA',
#  'Częstochowa',
#  'Dayton, OH',
#  'Denver, CO',
#  'Des Moines, IA',
#  'Didymoteicho',
#  'Dordrecht',
#  'Dortmund',
#  'Dresden',
#  'Drniš',
#  'Drobeta',
#  'Dublin',
#  'Dugopolje',
#  'Duisburg',
#  'Dvůr Králové',
#  'Düsseldorf',
#  'Edinburgh',
#  'Eifel e-Bike',
#  'El Paso, TX',
#  'Ellmau',
#  'Elmas',
#  'Enna',
#  'Ennetmoos',
#  'Ente Parco Montemarcello Magra',
#  'Epinal',
#  'Eppelheim',
#  'Erfurt',
#  'Esch-sur-alzette',
#  'Essen',
#  'Exeter',
#  'Fargo, ND',
#  'Ferrara',
#  'Ferrol - Narón',
#  'Florina',
#  'Focșani',
#  'Forlì',
#  'Fort Lauderdale, FL',
#  'Fort Worth, TX',
#  'Fortaleza',
#  'Frankfurt',
#  'Freiburg',
#  'Fribourg',
#  'Frosinone',
#  'Frýdek-Místek',
#  'Fuerteventura',
#  'Gaeta',
#  'Gallipoli',
#  'Galway',
#  'Gandía',
#  'Gelsenkirchen',
#  'Genova',
#  'Gent',
#  'Getafe',
#  'Gießen',
#  'Girona',
#  'Glasgow',
#  'Glyfada',
#  'Goiânia',
#  'Graben',
#  'Gran Canaria',
#  'Greenville, SC',
#  'Greifswald (StadtRad)',
#  'Grodzisk Mazowiecki',
#  'Groß Enzersdorf',
#  'Guadalajara',
#  'Göteborg',
#  'Gütersloh',
#  'Hamburg',
#  'Hamilton, ON',
#  'Hamm',
#  'Hannover',
#  'Havířov',
#  'Heidelberg',
#  'Helsinki',
#  'Heppenheim',
#  'Hergiswil',
#  'Herne',
#  'Hlučín',
#  'Hockenheim',
#  'Hollabrunn',
#  'Horw',
#  'Houston, TX',
#  'Hradec Králové',
#  'Hvar',
#  'Ibiza-City',
#  'Igoumenitsa',
#  'Imola',
#  'Indianapolis, IN',
#  'Innsbruck',
#  'Ioannina',
#  'Ipaússu',
#  'Irakleio',
#  'Istanbul',
#  'Ivanic Grad',
#  'Ivano Frankivsk',
#  'Izmir',
#  'Jastrebarsko',
#  'Jesi',
#  'Jihlava',
#  'Kaiserslautern',
#  'Kalisz',
#  'Kansas City, MO',
#  'Karditsa',
#  'Karlovac',
#  'Karlsruhe',
#  'Kassel',
#  'Katowice',
#  'Kavala',
#  'Ketchum / Sun Valley, ID',
#  'Kiel',
#  'Kinouria',
#  'Kladno',
#  'Klagenfurt',
#  'Kocaeli',
#  'Koluszki',
#  'Komorniki',
#  'Komotini',
#  'Konin',
#  'Koszalin',
#  'Kołobrzeg',
#  'Kraków',
#  'Kranjska Gora',
#  'Krnov',
#  'Kufstein',
#  'Kutno',
#  'Kuřim',
#  'Köln',
#  'Kędzierzyn-Koźle',
#  'Kιato',
#  'La Baule-Escoublac',
#  'La Chantrerie, Nantes',
#  'La Spezia',
#  'Lahr',
#  'Landau in der Pfalz',
#  'Lanzarote',
#  'Laon',
#  'Las Condes',
#  'Las Palmas de Gran Canaria',
#  'Las Vegas, NV',
#  'Lausanne',
#  'Lavis',
#  'Laško',
#  'Lecce',
#  'Lecco',
#  'Leipzig',
#  'Leverkusen',
#  'León',
#  'Lille',
#  'Lillestrøm',
#  'Limassol',
#  'Limerick',
#  'Limnos',
#  'Linz',
#  'Lippstadt',
#  'Lisbon',
#  'Livorno',
#  'Ljubljana',
#  'Lodi',
#  'London',
#  'Long Beach, NY',
#  'Los Angeles, CA',
#  'Lublin',
#  'Luboń',
#  'Ludwigshafen',
#  'Lugano',
#  'Lund',
#  'Luxembourg',
#  'Luzern',
#  'Lviv',
#  'Lyon',
#  'MV-Rad',
#  'Madison, WI',
#  'Madrid',
#  'Mainz',
#  'Makarska',
#  'Malmö',
#  'Malta',
#  'Manerba del Garda',
#  'Mani',
#  'Mannheim',
#  'Mantova',
#  'Marathon',
#  'Marburg',
#  'Marciana Marina',
#  'Maribor',
#  'Marki',
#  'Maroussi',
#  'Marseillan',
#  'Marseille',
#  'Medellin',
#  'Melbourne',
#  'Melbourne, AU',
#  'Metković',
#  'Mezzocorona',
#  'Mezzolombardo',
#  'Miami Beach, FL',
#  'Milano',
#  'Milton Keynes',
#  'Milwaukee, WI',
#  'Minneapolis, MN',
#  'Mladá Boleslav',
#  'Mnichovo Hradiště',
#  'Modena',
#  'Monaco',
#  'Monopoli',
#  'Monserrato',
#  'Montecatini Terme',
#  'Montpellier',
#  'Montréal, QC',
#  'Monza',
#  'Morigerati',
#  'Moscow',
#  'Mulhouse',
#  'Murcia',
#  'Murmansk',
#  'Mödling',
#  'Mönchengladbach',
#  'Mülheim a.d.R.',
#  'Nafplio',
#  'Namur',
#  'Nancy',
#  'Nantes',
#  'Neusiedler See',
#  'New York, NY',
#  'Nice',
#  'Nicosia',
#  'Niort',
#  'Nitra',
#  'Nizhniy Novgorod',
#  'Norderstedt',
#  'Noto',
#  'Nova Gorica',
#  'Novara',
#  'Nyon',
#  'Nürnberg',
#  'Oberdorf',
#  'Oberhausen',
#  'Odessa',
#  'Offenburg',
#  'Oklahoma, OK',
#  'Olbia',
#  'Oldenburg',
#  'Olesno',
#  'Olomouc',
#  'Omaha, NE',
#  'Opava',
#  'Općina Hrvace',
#  'Općina Klis',
#  'Općina Otok Dalmatinski',
#  'Orlando, FL',
#  'Orlen Płock',
#  'Osijek',
#  'Oslo',
#  'Ostrava',
#  'Ostrów Wielkopolski',
#  'Otwock',
#  'Pabianice',
#  'Padova',
#  'Palma',
#  'Pamplona',
#  'Parco Naturale Molentargius - Saline',
#  'Parco Nazionale del Circeo',
#  'Parco Nazionale del Gargano',
#  'Parco dei Colli di Bergamo',
#  'Parco naturale Migliarino San Rossore Massaciuccoli',
#  'Pardubice',
#  'Paris',
#  'Paris-Saclay',
#  'Parma',
#  'Patra',
#  'Pau',
#  'Pavia',
#  'Perugia',
#  'Petrolina',
#  'Philadelphia, PA',
#  'Phoenix, AZ',
#  'Piacenza',
#  'Piaseczno',
#  'Pielgrzymka',
#  'Pinerolo',
#  'Piotrków Trybunalski',
#  'Pisa',
#  'Pitomača',
#  'Pittsburgh',
#  'Pizzighettone e Formigara',
#  'Pobiedziska',
#  'Podstrana',
#  'Ponferrada',
#  'Pordenone',
#  'Poreč',
#  'Portland, OR',
#  'Porto Alegre',
#  'Porto Torres',
#  'Portorož',
#  'Potsdam',
#  'Poznań',
#  'Praha',
#  'Prata Camportaccio',
#  'Prešov',
#  'Prostejov',
#  'Pruszków',
#  'Pszczyna',
#  'Písek',
#  'Płock',
#  'Quartucciu',
#  'Quickborn',
#  'Québec',
#  'RSVG',
#  'RVK e-Bike',
#  'Recife',
#  'Reggio Emilia',
#  'Reims',
#  'Rennes',
#  'Rethymno',
#  'Reykjavík',
#  'Rhodes',
#  'Rieti',
#  'Rimini',
#  'Rio de Janeiro',
#  'Rivarolo Canavese',
#  'Rosario',
#  'Rouen',
#  'Rovereto',
#  'Rychnovsko',
#  'Rüsselsheim am Main',
#  'Rīga',
#  'Saguenay',
#  'Saint-Brieuc',
#  'Saint-Nazaire',
#  'Saint-Étienne',
#  'Salt Lake City',
#  'Saluzzo',
#  'Salvador',
#  'Samos',
#  'San Antonio, TX',
#  'San Donato Milanese',
#  'San Francisco Bay Area, CA',
#  'San Giovanni in Persiceto',
#  'San Lazzaro di Savena',
#  'San Luis Potosi',
#  "San Michele All'adige",
#  'San Ramon, CA',
#  'San Teodoro',
#  'Santa Margherita Ligure - Portofino - Camogli',
#  'Santa Maria Maggiore - Malesco - Villette',
#  'Santander',
#  'Santiago',
#  'Santos',
#  'Sarajevo',
#  'Sarnen',
#  'Saturn',
#  'Savigliano',
#  'Savona',
#  'Scafati',
#  'Scandiano',
#  'Scandicci',
#  'Schio',
#  'Schwetzingen',
#  'Selargius',
#  'Sellero',
#  'Serfaus',
#  'Sestri Levante - Lavagna',
#  'Sevilla',
#  'Shymkent',
#  'Siemianowice Śląskie',
#  'Siena',
#  'Sieradz',
#  'Sierre',
#  'Sinj',
#  'Sion',
#  'Sisak',
#  'Skierniewice',
#  'Slavonski Brod',
#  'Slough',
#  'Soissons',
#  'Sokołów Podlaski',
#  'Solin',
#  'Sondrio',
#  'Sorocaba',
#  'Sosnowiec',
#  'Spartanburg, SC',
#  'Speyer',
#  'Split',
#  'St.Pölten',
#  'Stans',
#  'Stansstad',
#  'Stirling',
#  'Strasbourg',
#  'Surrey',
#  'Sursee',
#  'Swansea',
#  'Szamotuły',
#  'Szczecin',
#  'São Lourenço',
#  'São Paulo',
#  'TV',
#  'Tampa, FL',
#  'Tarbes, Lourdes',
#  'Tarnów',
#  "Tel Aviv-Yaffo, Giv'atayim, Ramat-Gan",
#  'Terni',
#  'Thermenregion',
#  'Thessaloniki',
#  'Tirano',
#  'Topeka, KS',
#  'Torino',
#  'Toronto, ON',
#  'Tortolì',
#  'Toulouse',
#  'Tradate',
#  'Trento',
#  'Treviglio',
#  'Treviso',
#  'Trieste',
#  'Trogir',
#  'Trondheim',
#  'Troyes',
#  'Tulln',
#  'Turku',
#  'Tuzla',
#  'Tychy',
#  'Udine',
#  'Ugento',
#  'Uherské Hradiště',
#  'University of South Florida, FL',
#  'University of Virginia, VA',
#  'Urdaibai',
#  'Usedom',
#  'Ustica',
#  "Val d'Ille-Aubigné",
#  'Valence',
#  'Valencia',
#  'Vancouver',
#  'Vannes',
#  'Varese',
#  'Velika Gorica',
#  'Venezia',
#  'Vercelli',
#  'Verona',
#  'Vicolungo',
#  'Vilagarcía de Arousa',
#  'Vilnius',
#  'Vinnytsia',
#  'Vrchlabí',
#  'Vukovar',
#  'Vřesina',
#  'Wachau',
#  'Wageningen',
#  'Walldorf',
#  'Warszawa',
#  'Washington, DC',
#  'Weinheim',
#  'Wien',
#  'WienerWald',
#  'Wiesbaden',
#  'Winsen (Luhe)',
#  'Wolfenschiessen',
#  'Wolt',
#  'Worms',
#  'Wr.Neustadt',
#  'Wrocław',
#  'Würzburg',
#  'Zadar',
#  'Zagorje ob Savi',
#  'Zagreb',
#  'Zaprešić',
#  'Zaragoza',
#  'Zduńska Wola',
#  'Zgierz',
#  'Zielona Góra',
#  'Zlín',
#  'Zürich',
#  'Łask',
#  'Łomża',
#  'Łowicz',
#  'Łódź',
#  'Říčany',
#  'Šibenik',
#  'Żyrardów',
#  'Žilina',
#  'Αrxaia Olympia',
#  'Μoschato-Tavros',
#  'Νea Smyrni',
#  '富山市']

# %%
cities = set()  # Using a set to store unique cities

for network in city_bikes['networks']:
    city = network['location']['city']
    country = network['location']['country']
    cities.add((city, country))  # Store city and country as a tuple

unique_cities = list(cities)  # Convert the set back to a list

unique_cities.sort()
# unique_cities

# %%
# narrow down our choices to Canadian cities for better understanding of locations
for city in unique_cities:
  if city[1] == 'CA':
    print(city)
# Out:
# ('Hamilton, ON', 'CA')
# ('Montréal, QC', 'CA')
# ('Québec', 'CA')
# ('Saguenay', 'CA')
# ('Toronto, ON', 'CA')
# ('Vancouver', 'CA')

# %% [markdown]
# ## Start API function calls

# %%
# select a city for future functions to use
city = "Vancouver"

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
def get_city_data(city):
  city_bikes = requests.get("http://api.citybik.es/v2/networks").json()

  list_of_dicts = []
  for city_bike_dict in city_bikes['networks']:
    new_city = city_bike_dict['location']['city']
    if new_city.lower() == city.lower():
      list_of_dicts.append(city_bike_dict)
  return list_of_dicts

# %%
station_dict = get_city_data(city)
station_dict
# RETURNS:
# [{'company': ['Vanncouver Bike Share Inc.',
#    'CycleHop LLC',
#    'City of Vancouver',
#    'Shaw Communications Inc.',
#    'Fifteen'],
#   'gbfs_href': 'https://vancouver-gbfs.smoove.pro/gbfs/2/gbfs.json',
#   'href': '/v2/networks/mobibikes',
#   'id': 'mobibikes',
#   'location': {'city': 'Vancouver',
#    'country': 'CA',
#    'latitude': 49.2827,
#    'longitude': -123.1207},
#   'name': 'Mobi'}]
# Out:
# [{'company': ['Vanncouver Bike Share Inc.',
#    'CycleHop LLC',
#    'City of Vancouver',
#    'Shaw Communications Inc.',
#    'Fifteen'],
#   'gbfs_href': 'https://vancouver-gbfs.smoove.pro/gbfs/2/gbfs.json',
#   'href': '/v2/networks/mobibikes',
#   'id': 'mobibikes',
#   'location': {'city': 'Vancouver',
#    'country': 'CA',
#    'latitude': 49.2827,
#    'longitude': -123.1207},
#   'name': 'Mobi'}]

# %%
# debug testing of output
station_dict[0]['href']
# SAMPLE RESULTS:
# /v2/networks/mobibikes
# Out:
# '/v2/networks/mobibikes'

# %%
def get_stations_info(city):
  station_dict = get_city_data(city)
  if not station_dict:
    print("Error: No bike company found for {}",format(city))
    return None

  network_address=station_dict[0]['href']
  url="http://api.citybik.es/{}".format(network_address)
  return requests.get(url).json()['network']['stations']
# The full network URL here is http://api.citybik.es/v2/networks/velib

# %%
# debug testing of output
station_info = get_stations_info(city)
#station_info

# SAMPLE RESULTS
# [{'empty_slots': 32,
#   'extra': {'ebikes': 0,
#    'has_ebikes': True,
#    'last_updated': 1685669893,
#    'normal_bikes': 3,
#    'renting': True,
#    'returning': True,
#    'slots': 35,
#    'uid': '0001'},
#   'free_bikes': 3,
#   'id': '7a19c49f486d7c0c02b3685d7b240448',
#   'latitude': 49.262487,
#   'longitude': -123.114397,
#   'name': '10th & Cambie',
#   'timestamp': '2023-06-02T01:43:36.724000Z'},
#  {'empty_slots': 11,
#   'extra': {'ebikes': 2,
#    'has_ebikes': True,
#    'last_updated': 1685669744,
#    'normal_bikes': 3,
#    'renting': True,
#    'returning': True,
#    'slots': 16,
#    'uid': '0004'},
#   'free_bikes': 5,
#   'id': '32603a87cfca71d0f7dfa3513bad69d5',
#   'latitude': 49.274566,
#   'longitude': -123.121817,
#   'name': 'Yaletown-Roundhouse Station',
#   'timestamp': '2023-06-02T01:43:36.722000Z'}]

# %% [markdown]
# ## Place API results into Dataframe

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
def get_available_stations(city):
  '''
  Takes in the city name and returns a pandas dataframe containing information about the city
  '''
  if city is None or city == "":
    print("City missing.")
    return None
  station_info = get_stations_info(city)


  station_list = []
  for info in station_info:
    a_dict = {
        'city': city,
        'station_name': info['name'],
        'empty_slots': info['empty_slots'],
        'slots': info['extra']['slots'],
        'free_bikes': info['free_bikes'],
        'ebikes': info['extra']['ebikes'],
        #'normal_bikes': info['extra']['normal_bikes'],
        #'payment': ','.join(info['extra']['payment']) if info['extra']['banking'] else "No",
        'latitude': info['latitude'],
        'longitude': info['longitude'],
        'timestamp': info['timestamp'], # needed for graphs
        #'Unique ID': info['extra']['uid'],
    }
    station_list.append(a_dict)
  return pd.DataFrame(station_list)

# %%
df = get_available_stations(city)

# %%
df
# Out:
#           city                 station_name  empty_slots  slots  free_bikes  \
# 0    Vancouver                10th & Cambie           15     35          20
# 1    Vancouver  Yaletown-Roundhouse Station            4     16          12
# 2    Vancouver            Dunsmuir & Beatty           15     26          11
# 3    Vancouver     12th & Yukon (City Hall)           13     16           3
# 4    Vancouver                    8th & Ash           13     16           3
# ..         ...                          ...          ...    ...         ...
# 237  Vancouver               Burrard & 14th           15     18           1
# 238  Vancouver               Hornby & Drake           17     24           7
# 239  Vancouver           Cardero & Bayshore            5     20          13
# 240  Vancouver                  27th & Main           19     22           3
# 241  Vancouver          Cordova & Granville            4     18          12
#
#      ebikes   latitude   longitude                    timestamp
# 0         5  49.262487 -123.114397  2023-06-03T20:42:11.861000Z
# 1         2  49.274566 -123.121817  2023-06-03T20:42:11.857000Z
# 2         0  49.279764 -123.110154  2023-06-03T20:42:11.858000Z
# 3         3  49.260599 -123.113504  2023-06-03T20:42:11.859000Z
# 4         0  49.264215 -123.117772  2023-06-03T20:42:11.906000Z
# ..      ...        ...         ...                          ...
# 237       1  49.259469 -123.145718  2023-06-03T20:42:11.799000Z
# 238       0  49.277178 -123.130000  2023-06-03T20:42:11.817000Z
# 239       0  49.291597 -123.129158  2023-06-03T20:42:11.757000Z
# 240       2  49.247204 -123.101549  2023-06-03T20:42:12.018000Z
# 241       1  49.285670 -123.112543  2023-06-03T20:42:12.036000Z
#
# [242 rows x 9 columns]

# %%
# how to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# write city_bikes location dataframe to csv
# save our API calls and work to a hard copy file
# df.to_csv('/content/drive/MyDrive/Colab Notebooks/datasets/Project-Statistics_city_bikes.csv', index=False)

# %% [markdown]
# ## Show API Results in Visualizations (maps/charts)

# %% [markdown]
# Show information map.

# %%
# FAILs to run in Google Colab
# def show_map(station_data):
#   '''
#   Takes in data of the station info in a dataframe format then
#   Shows it on a map
#   '''
#   # get the current data and time
#   current_date = pd.to_datetime(station_data['timestamp'][0]).strftime('%a %d %B %Y at %H:%M')

#   map_title = 'Map Showing Number of Bikes in {} at {}'.format(city, current_date)

#   fig = px.scatter_mapbox(station_data, lat="latitude",lon="longitude", hover_name="station_name", color="free_bikes",
#                           hover_data=["empty_slots", "free_bikes", "ebikes"],
#                           title=map_title,
#                           color_continuous_scale=px.colors.sequential.Plasma,
#                           size_max=20,
#                           zoom=12)
#   fig.show(renderer="colab")

# %%
#! pip install plotly --upgrade # my plotly.express map was not showing now at 5.14.1

# %%
# !pip show plotly
# Name: plotly
# Version: 5.13.1
# Summary: An open-source, interactive data visualization library for Python
# Home-page: https://plotly.com/python/
# Author: Chris P
# Author-email: chris@plot.ly
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: tenacity
# Required-by: cufflinks, datascience

# %%
# confirm latest version installed as I was having display problems of the maps/plots
# import plotly
# plotly.__version__
# RETURNS 5.13.1

# %%
# show map rewrite to render in Google Colab
import folium

def show_map(live_data):
    '''
    Takes in the live data Pandas dataframe to show a map of the stations,
    return nothing.
    '''

    if live_data.empty:
        print("Error: Station data is not available!")
        return None

    # Create a map centered around the latitude and longitude of the first station
    map = folium.Map(location=[live_data['latitude'].iloc[0], live_data['longitude'].iloc[0]], zoom_start=13)

    # Add markers for each station
    for index, row in live_data.iterrows():
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=row['station_name'],
            icon=folium.Icon(color='blue')
        ).add_to(map)

    # Display the map
    display(map)

# %%
df_bikes = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets/Project-Statistics_city_bikes_yelp.csv')

# %%
df_filtered = df_bikes.sort_values("yelp_review_count", ascending=False).head(10)

# %%
# most popular reviewed parks near stations
show_map(df_filtered)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06fb8ca3d4bdd2734f12abb7c93e9e93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06fb8ca3d4bdd2734f12abb7c93e9e93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06fb8ca3d4bdd2734f12abb7c93e9e93 = L.map(
#                 &quot;map_06fb8ca3d4bdd2734f12abb7c93e9e93&quot;,
#                 {
#                     center: [49.289255, -123.132677],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7481241d2265618f19f0ba6195382c2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_06fb8ca3d4bdd2734f12abb7c93e9e93);
#
#
#             var marker_c78ec39e10658b02fce045ff53195706 = L.marker(
#                 [49.289255, -123.132677],
#                 {}
#             ).addTo(map_06fb8ca3d4bdd2734f12abb7c93e9e93);
#
#
#             var icon_8a0b1bd66f42360db3e80ea33d21a934 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c78ec39e10658b02fce045ff53195706.setIcon(icon_8a0b1bd66f42360db3e80ea33d21a934);
#
#
#         var popup_f32e91acf39b25b2ff5a573a7b570b06 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c9b1c81de8846be45d2e158565067506 = $(`&lt;div id=&quot;html_c9b1c81de8846be45d2e158565067506&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cardero &amp; Robson&lt;/div&gt;`)[0];
#                 popup_f32e91acf39b25b2ff5a573a7b570b06.setContent(html_c9b1c81de8846be45d2e158565067506);
#
#
#
#         marker_c78ec39e10658b02fce045ff53195706.bindPopup(popup_f32e91acf39b25b2ff5a573a7b570b06)
#         ;
#
#
#
#
#             var marker_2768b53204839d4d9cae3f021dcdb4ad = L.marker(
#                 [49.291909, -123.140713],
#                 {}
#             ).addTo(map_06fb8ca3d4bdd2734f12abb7c93e9e93);
#
#
#             var icon_436093826b116c23736ced4eb4d39f62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2768b53204839d4d9cae3f021dcdb4ad.setIcon(icon_436093826b116c23736ced4eb4d39f62);
#
#
#         var popup_9e71d2a731bcf4f8ddb6decb812ce0a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16e5495a18e702e2182ad10b13e3aac2 = $(`&lt;div id=&quot;html_16e5495a18e702e2182ad10b13e3aac2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chilco &amp; Barclay&lt;/div&gt;`)[0];
#                 popup_9e71d2a731bcf4f8ddb6decb812ce0a9.setContent(html_16e5495a18e702e2182ad10b13e3aac2);
#
#
#
#         marker_2768b53204839d4d9cae3f021dcdb4ad.bindPopup(popup_9e71d2a731bcf4f8ddb6decb812ce0a9)
#         ;
#
#
#
#
#             var marker_26a69d3c242db1e2a4ce8a4a1df1fe61 = L.marker(
#                 [49.290587, -123.13625],
#                 {}
#             ).addTo(map_06fb8ca3d4bdd2734f12abb7c93e9e93);
#
#
#             var icon_a7ae7633c6d4c1f2a11843a259f35c5f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_26a69d3c242db1e2a4ce8a4a1df1fe61.setIcon(icon_a7ae7633c6d4c1f2a11843a259f35c5f);
#
#
#         var popup_98aa508aaac5324a8a364e3aa1aac925 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97fbadb160c0ea52181dce2839424fcd = $(`&lt;div id=&quot;html_97fbadb160c0ea52181dce2839424fcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Haro &amp; Denman&lt;/div&gt;`)[0];
#                 popup_98aa508aaac5324a8a364e3aa1aac925.setContent(html_97fbadb160c0ea52181dce2839424fcd);
#
#
#
#         marker_26a69d3c242db1e2a4ce8a4a1df1fe61.bindPopup(popup_98aa508aaac5324a8a364e3aa1aac925)
#         ;
#
#
#
#
#             var marker_24ebaae15c27e29630239f22180ee9c7 = L.marker(
#                 [49.28972, -123.144028],
#                 {}
#             ).addTo(map_06fb8ca3d4bdd2734f12abb7c93e9e93);
#
#
#             var icon_4934532036fff384366d256beaa5aef9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,

# %%
live_station_data = get_available_stations(city)
show_map(live_station_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3140422f2e7d422562f2230e3b208af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3140422f2e7d422562f2230e3b208af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3140422f2e7d422562f2230e3b208af = L.map(
#                 &quot;map_e3140422f2e7d422562f2230e3b208af&quot;,
#                 {
#                     center: [49.262487, -123.114397],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_776717d97dfddd252b47149046ad8eda = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3140422f2e7d422562f2230e3b208af);
#
#
#             var marker_ddc6baa7997a80e00991f69475d02d02 = L.marker(
#                 [49.262487, -123.114397],
#                 {}
#             ).addTo(map_e3140422f2e7d422562f2230e3b208af);
#
#
#             var icon_8e842936a99c179a75981226db0eb1eb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ddc6baa7997a80e00991f69475d02d02.setIcon(icon_8e842936a99c179a75981226db0eb1eb);
#
#
#         var popup_cfdb91938472e445582efc4c11206dd4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba56033d1d2db235fc0518db4d2ca1ed = $(`&lt;div id=&quot;html_ba56033d1d2db235fc0518db4d2ca1ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10th &amp; Cambie&lt;/div&gt;`)[0];
#                 popup_cfdb91938472e445582efc4c11206dd4.setContent(html_ba56033d1d2db235fc0518db4d2ca1ed);
#
#
#
#         marker_ddc6baa7997a80e00991f69475d02d02.bindPopup(popup_cfdb91938472e445582efc4c11206dd4)
#         ;
#
#
#
#
#             var marker_818b6fdce454131b70602ce534b76e98 = L.marker(
#                 [49.274566, -123.121817],
#                 {}
#             ).addTo(map_e3140422f2e7d422562f2230e3b208af);
#
#
#             var icon_69c6a3908df5dfadc17bf246facbe0cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_818b6fdce454131b70602ce534b76e98.setIcon(icon_69c6a3908df5dfadc17bf246facbe0cc);
#
#
#         var popup_af7f7d15e8ecca644fbe16405b4a9288 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ac5579ebc2bd6225501478189edb8f3 = $(`&lt;div id=&quot;html_1ac5579ebc2bd6225501478189edb8f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Yaletown-Roundhouse Station&lt;/div&gt;`)[0];
#                 popup_af7f7d15e8ecca644fbe16405b4a9288.setContent(html_1ac5579ebc2bd6225501478189edb8f3);
#
#
#
#         marker_818b6fdce454131b70602ce534b76e98.bindPopup(popup_af7f7d15e8ecca644fbe16405b4a9288)
#         ;
#
#
#
#
#             var marker_0da9984534bb39e23df449997f8b8741 = L.marker(
#                 [49.279764, -123.110154],
#                 {}
#             ).addTo(map_e3140422f2e7d422562f2230e3b208af);
#
#
#             var icon_ec7f0ce063e7011435cdb0440c1a177c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0da9984534bb39e23df449997f8b8741.setIcon(icon_ec7f0ce063e7011435cdb0440c1a177c);
#
#
#         var popup_beed0ae6de747ce2245a1ea37035f4ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d26a026a7e2ffef94adbd89768f4dc0b = $(`&lt;div id=&quot;html_d26a026a7e2ffef94adbd89768f4dc0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dunsmuir &amp; Beatty&lt;/div&gt;`)[0];
#                 popup_beed0ae6de747ce2245a1ea37035f4ad.setContent(html_d26a026a7e2ffef94adbd89768f4dc0b);
#
#
#
#         marker_0da9984534bb39e23df449997f8b8741.bindPopup(popup_beed0ae6de747ce2245a1ea37035f4ad)
#         ;
#
#
#
#
#             var marker_64c6d53a57a9729ff59405c16805fc8f = L.marker(
#                 [49.260599, -123.113504],
#                 {}
#             ).addTo(map_e3140422f2e7d422562f2230e3b208af);
#
#
#             var icon_4d0e7b3b7ec8503cc717dc40d3989a6b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate

# %%
# FAILs to load in Google Colab
# v2 but no display
# def show_pie_chart(live_data, station_name):
#     '''
#     Takes in the live data Pandas dataframe and requested station_name to
#     show a pie chart, return nothing.
#     '''

#     if live_data.empty:
#         print("Error: Station data is not available!")
#         return None

#     requested_station_data = live_data[live_data["station_name"].map(lambda name: station_name.lower() in name.lower())]

#     if requested_station_data.empty:
#         print("Error: Requested station not found!")
#         return None

#     current_date = pd.to_datetime(requested_station_data['timestamp'].iloc[0]).strftime('%a %d %B %Y at %H:%M')

#     title = "Bike information for: {0} at {1}".format(
#         requested_station_data["station_name"].to_string(index=False),
#         current_date)

#     fig = px.pie(requested_station_data, values=["empty_slots", "free_bikes", "ebikes"],
#                  names=["Empty Slots", "Free Bikes", "ebikes"],
#                  hole=.3,
#                  title=title)

#     fig.update_traces(textposition='inside',
#                       textinfo='value+label')

#     fig.show()

# %% [markdown]
# If the pie chart is not being displayed in Google Colab, it could be due to the rendering settings or limitations of the Colab environment. To ensure that the chart is displayed, you can try using the plotly.offline mode with the iplot function.
#
# Here's an updated version of the show_pie_chart function that uses plotly.offline.

# %%
import plotly.offline as pyo
import plotly.graph_objs as go

def show_pie_chart(live_data, station_name):
    '''
    Takes in the live data Pandas dataframe and requested station_name to
    show a pie chart, return nothing.
    '''

    if live_data.empty:
        print("Error: Station data is not available!")
        return None

    requested_station_data = live_data[live_data["station_name"].map(lambda name: station_name.lower() in name.lower())]

    if requested_station_data.empty:
        print("Error: Requested station not found!")
        return None

    current_date = pd.to_datetime(requested_station_data['timestamp'].iloc[0]).strftime('%a %d %B %Y at %H:%M')

    title = "Bike information for: {0} at {1}".format(
        requested_station_data["station_name"].to_string(index=False),
        current_date)

    data = [
        go.Pie(
            labels=["Empty Slots", "Free Bikes", "ebikes"],
            values=[requested_station_data["empty_slots"].iloc[0],
                    requested_station_data["free_bikes"].iloc[0],
                    requested_station_data["ebikes"].iloc[0]],
            hole=0.3,
            textposition='inside',
            textinfo='value+label'
        )
    ]

    layout = go.Layout(title=title)

    fig = go.Figure(data=data, layout=layout)

    pyo.iplot(fig)

# %%
live_city_data = get_available_stations(city)
show_pie_chart(live_city_data,city)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8263e098-6ad2-4de5-9321-f05a9a27d315" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8263e098-6ad2-4de5-9321-f05a9a27d315")) {                    Plotly.newPlot(                        "8263e098-6ad2-4de5-9321-f05a9a27d315",                        [{"hole":0.3,"labels":["Empty Slots","Free Bikes","ebikes"],"textinfo":"value+label","textposition":"inside","values":[11,9,0],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}] ...
